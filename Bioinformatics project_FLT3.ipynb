# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# traget search for proteins
target = new_client.target
target_query = target.search('FLT3')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0                                                 []  Mus musculus
# 1  [{'xref_id': 'P36888', 'xref_name': None, 'xre...  Homo sapiens
#
#                                     pref_name  score  species_group_flag  \
# 0  Receptor-type tyrosine-protein kinase FLT3   18.0               False
# 1       Tyrosine-protein kinase receptor FLT3   16.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL2034796  [{'accession': 'Q00342', 'component_descriptio...
# 1       CHEMBL1974  [{'accession': 'P36888', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN   10090
# 1  SINGLE PROTEIN    9606

# %% [markdown]
# ### Select and retrieve bioactivity data for SARS coronavirus 3C-like proteinase(5th entry)

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL1974'

# %%
activity = new_client.activity
result = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')

# %%
df = pd.DataFrame.from_dict(result)
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None       866063                  []    CHEMBL766072
# 1                None       872532                  []    CHEMBL766072
# 2                None       872564                  []    CHEMBL766072
# 3                None       879718                  []    CHEMBL766072
# 4                None       884645                  []    CHEMBL766072
# ...               ...          ...                 ...             ...
# 3459             None     18812774                  []   CHEMBL4276335
# 3460             None     18812784                  []   CHEMBL4276335
# 3461             None     18812789                  []   CHEMBL4276335
# 3462             None     18812794                  []   CHEMBL4276335
# 3463             None     18812804                  []   CHEMBL4276335
#
#                                       assay_description assay_type  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('Tyrosine-protein kinase receptor FLT3 bioactivity_data.csv', index=False)

# %%
# !ls -l
# Out:
# total 71520
# -rw-rw-r-- 1 edie738 edie738    12709 Jul 16 00:58  Accessing_Databases.ipynb
# -rw-rw-r-- 1 edie738 edie738     3869 Jul 14 16:22  Basic_Sequence_Processing.ipynb
# -rw-rw-r-- 1 edie738 edie738    70010 Jul 18 02:58  bioactivity_data.csv
# -rw-rw-r-- 1 edie738 edie738    82458 Jul 20 23:08 'Bioinformatics project.ipynb'
# -rw-rw-r-- 1 edie738 edie738   211847 Jul 20 17:39  CDD_ML_Part_2_Exploratory_Data_Analysis.ipynb
# -rw-rw-r-- 1 edie738 edie738   208719 Jul 20 19:17  CDD_ML_Part_3_Acetylcholinesterase_Descriptor_Dataset_Preparation.ipynb
# -rw-rw-r-- 1 edie738 edie738   100095 Jul 20 19:17  CDD_ML_Part_4_Acetylcholinesterase_Regression_Random_Forest.ipynb
# -rw-rw-r-- 1 edie738 edie738   308736 Jul 17 14:34  cheminformatics_predicting_solubility.ipynb
# -rw-rw-r-- 1 edie738 edie738    18311 Jul 18 03:33  cholera_bioactivity_data.csv
# drwxrwxr-x 3 edie738 edie738     4096 Jul 20 13:00  drug_project
# ...

# %% [markdown]
# ### Handling missing values

# %%
df2 = df[df.standard_value.notna()]
df2.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None     12692834                  []   CHEMBL2341094
# 1             None     12692835                  []   CHEMBL2341094
# 2             None     12692840                  []   CHEMBL2341094
# 3             None     12692841                  []   CHEMBL2341094
# 4             None     12692846                  []   CHEMBL2341094
#
#                                    assay_description assay_type bao_endpoint  \
# 0  Inhibition of human S100B/human TAMRA-p53(367-...          B  BAO_0000190
# 1  Inhibition of human S100B/human TAMRA-p53(367-...          B  BAO_0000190
# 2  Inhibition of human S100B/human TAMRA-p53(367-...          B  BAO_0000190
# 3  Inhibition of human S100B/human TAMRA-p53(367-...          B  BAO_0000190
# 4  Inhibition of human S100B/human TAMRA-p53(367-...          B  BAO_0000190
#
#     bao_format              bao_label  \
# 0  BAO_0000357  single protein format
# ...

# %%
df2.standard_value[0]
# Out:
# '100000.0'

# %% [markdown]
# ### IC50 reflects the concentration required to produce the inhibition effect. Hence the less the concentration the more efficient the drug

# %%
bioactivity_class = []
for i in df2.standard_value:
    if float(i) <= 1000:
        bioactivity_class.append('active')
    elif float(i) >= 10000:
        bioactivity_class.append('inactive')
    else:
        bioactivity_class.append('intermdediate')

# %%
bioactivity_class
# Out:
# ['inactive',
#  'intermdediate',
#  'intermdediate',
#  'intermdediate',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive']

# %%
df2.molecule_chembl_id[0]
# Out:
# 'CHEMBL187579'

# %%
df2.assay_chembl_id[0]
# Out:
# 'CHEMBL829584'

# %%
mol_cid=[]
for i in df2.molecule_chembl_id:
    mol_cid.append(i)

# %%
cano_sm = []
for i in df2.canonical_smiles:
    cano_sm.append(i)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value
# 0           7200.0
# 1           9400.0
# ...

# %%
df4 = pd.concat([df3, pd.Series(bioactivity_class, name='Bioactivity_class')], axis= 1)

# %%
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value Bioactivity_class
# 0           7200.0     intermdediate
# ...

# %%
df4.to_csv('preprocessed_bioactivity_data', index=False)

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# .

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski 
import numpy as np

# %%
df5 = pd.read_csv('preprocessed_bioactivity_data')

# %%
# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation

def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df5.canonical_smiles)

# %%
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    281.271  1.89262         0.0            5.0
# 1    415.589  3.81320         0.0            2.0
# 2    421.190  2.66050         0.0            4.0
# 3    293.347  3.63080         0.0            3.0
# 4    338.344  3.53900         0.0            5.0
# ..       ...      ...         ...            ...
# 128  338.359  3.40102         0.0            5.0
# 129  296.366  3.44330         0.0            3.0
# 130  276.291  4.09564         0.0            3.0
# 131  278.307  3.29102         0.0            3.0
# 132  282.383  4.10530         0.0            2.0
#
# [133 rows x 4 columns]

# %%
df_combined = pd.concat([df5, df_lipinski], axis = 1)

# %%
df_combined
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#      standard_value Bioactivity_class       MW     LogP  NumHDonors  \
# ...

# %% [markdown]
# ## Convert IC50 to pIC50: A form dimentionality reduction to allow a more unifrom distribution of the values

# %%
# https://github.com/chaninlab/estrogen-receptor-alpha-qsar/blob/master/02_ER_alpha_RO5.ipynb

import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %%
df_combined.standard_value.describe()
# Out:
# count    1.330000e+02
# mean     8.017926e+12
# std      3.344888e+13
# min      5.000000e+01
# 25%      1.070000e+04
# 50%      2.350000e+04
# 75%      3.000000e+05
# max      3.311311e+14
# Name: standard_value, dtype: float64

# %% [markdown]
# too large values will return negative logs. so we need to deal with that

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)
        
    return x

# %%
df_norm = norm_value(df_combined)

# %%
df_norm.standard_value_norm.describe()
# Out:
# count    1.330000e+02
# mean     2.110164e+07
# std      4.089714e+07
# min      5.000000e+01
# 25%      1.070000e+04
# 50%      2.350000e+04
# 75%      3.000000e+05
# max      1.000000e+08
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     Bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# ...

# %%
df_final.pIC50.describe()
# Out:
# count    133.000000
# mean       4.060148
# std        1.783762
# min        1.000000
# 25%        3.522879
# 50%        4.628932
# 75%        4.970616
# max        7.301030
# Name: pIC50, dtype: float64

# %%
df_2class = df_final[df_final.Bioactivity_class != 'intermdediate']
df_2class
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 5         CHEMBL365134            O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21
# 7         CHEMBL190743             O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21
# 8         CHEMBL365469            O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     Bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# ...

# %% [markdown]
# ## **Exploratory Data Analysis (Chemical Space Analysis) via Lipinski descriptors**

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt
